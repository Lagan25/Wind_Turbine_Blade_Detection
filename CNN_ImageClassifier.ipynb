# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import os
import tensorflow as tf
import cv2
from tensorflow import keras
from tensorflow.keras.layers import  Dense, Input, InputLayer, Flatten
from tensorflow.keras.models import Sequential, Model
from  matplotlib import pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline

# %%
import random
plt.figure(figsize=(20,20))
img_folder=r'/content/drive/MyDrive/Blade_Turbine_Set/Damage_Area'
for i in range(5):
    file = random.choice(os.listdir(img_folder))
    image_path= os.path.join(img_folder, file)
    img=mpimg.imread(image_path)
    ax=plt.subplot(1,5,i+1)
    ax.title.set_text(file)
    plt.imshow(img)

# %%
damage_dir =r'/content/drive/MyDrive/Blade_Turbine_Set/Damage_Area'
erosion_dir =r'/content/drive/MyDrive/Blade_Turbine_Set/Erosion_Area'
edge_dir = r'/content/drive/MyDrive/Blade_Turbine_Set/Edge_Area'
reference_dir =r'/content/drive/MyDrive/Blade_Turbine_Set/Reference_Area'

# %%
print('total damaged images:', len(os.listdir(damage_dir)))
print('total erosion images:', len(os.listdir(erosion_dir)))
print('total edge area images:', len(os.listdir(edge_dir)))
print('total reference area images:', len(os.listdir(reference_dir)))
# Out:
# total damaged images: 234
# total erosion images: 195
# total edge area images: 90
# total reference area images: 240

# %%
train_damage_names = os.listdir(damage_dir)
print(train_damage_names[:5])

train_erosion_names = os.listdir(erosion_dir)
print(train_erosion_names[:5])

train_edge_names = os.listdir(edge_dir)
print(train_edge_names[:5])

train_reference_names = os.listdir(reference_dir)
print(train_reference_names[:5])
# Out:
# ['_7_6659643.png', '_14_517034.png', '_8_4166410.png', '_1_1940335.png', '_3_6344758.png']
# ['_16_2937492.png', '_12_2149596.png', '_15_3107984.png', '_0_6283996.png', '_1_8183550.png']
# ['_28_9347503.png', '_7_3212852.png', '_14_7505826.png', '_25_1717013.png', '_8_2966837.png']
# ['_13_7571898.png', '_10_779507.png', '_8_7701264.png', '_11_7641454.png', '_3_7352682.png']

# %%
nrows = 4
ncols = 4
pic_index = 0

fig = plt.gcf()
fig.set_size_inches(ncols * 4, nrows * 4)

pic_index += 8
next_damage_pix = [os.path.join(damage_dir, fname) 
                for fname in train_damage_names[pic_index-8:pic_index]]
next_erosion_pix = [os.path.join(erosion_dir, fname) 
                for fname in train_erosion_names[pic_index-8:pic_index]]

print ("Showing some damage pictures")
print()
for i, img_path in enumerate(next_damage_pix):
 
  sp = plt.subplot(nrows, ncols, i + 1)
  sp.axis('Off') 

  img = mpimg.imread(img_path)
  plt.imshow(img)

plt.show()

print ("Showing some erosion pictures")
print()
fig = plt.gcf()
fig.set_size_inches(ncols * 4, nrows * 4)
for i, img_path in enumerate(next_erosion_pix):
  
  sp = plt.subplot(nrows, ncols, i + 1)
  sp.axis('Off') 

  img = mpimg.imread(img_path)
  plt.imshow(img)
plt.show()
# Out:
# Showing some damage pictures
# Showing some erosion pictures

# %%
from keras.preprocessing.image import ImageDataGenerator
train_datagen = ImageDataGenerator(rescale=1/255)
batch_size = 646

dir = r'/content/drive/MyDrive/Blade_Turbine_Set'
train_generator = train_datagen.flow_from_directory(dir , 
        target_size=(320, 320),  
        batch_size=batch_size,
        classes = ['Damage_Area','Edge_Area','Erosion_Area','Reference_Area'],
        class_mode='categorical')

val_datagen = tf.keras.preprocessing.image_dataset_from_directory(
  dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  batch_size=batch_size)
# Out:
# Found 759 images belonging to 4 classes.
# Found 759 files belonging to 4 classes.
# Using 151 files for validation.

# %%
img_w, img_h = 220, 220

# %%
CLASSES, image = [], [] 
for root, dirs, files in os.walk(r'/content/drive/MyDrive/Blade_Turbine_Set'):
    f = os.path.basename(root)      
        
    if len(files) > 0:
        image.append(len(files))
        if f not in CLASSES:
            CLASSES.append(f) 
    
image_count = len(CLASSES) 
print('{} classes with {} images in total'.format(len(CLASSES), sum(image)))

f, ax = plt.subplots(figsize=(15,6))
if(image[0])<10:
    plt.bar(range(image_count ), image[image_count :], label = 'Train data')
    plt.bar(range(image_count ), image[0:image_count ], label = 'Test data')
else:
    plt.bar(range(image_count ), image[0:image_count ], label = 'Train data')
   
ax.grid()
ax.legend(fontsize = 12);
# Out:
# 4 classes with 759 images in total

# %%
def read_imgs_lbls(dir):
    Images, Labels = [], []
    for root, dirs, files in os.walk(dir):
        f = os.path.basename(root)        
        for file in files:
            Labels.append(f)
            try:
                image1 = cv2.imread(root+'/'+file)             
                image1 = cv2.resize(image1,(int(img_w*1.5), int(img_h*1.5)))       
                image1 = cv2.cvtColor(image1, cv2.COLOR_BGR2RGB)
                Images.append(image1)
            except Exception as e:
                print(e)
    Images = np.array(Images)
    return (Images, Labels)

# %%
def get_class_index(Labels):
    for i, n in enumerate(Labels):
        for j, k in enumerate(CLASSES):  
            if n == k:
                Labels[i] = j
    Labels = np.array(Labels)
    return Labels

# %%
_dir = r'/content/drive/MyDrive/Blade_Turbine_Set'
Train_Imgs, Train_Lbls = read_imgs_lbls(_dir)
Train_Lbls = get_class_index(Train_Lbls)
print('Shape of train images: {}'.format(Train_Imgs.shape))
print('Shape of train labels: {}'.format(Train_Lbls.shape))
# Out:
# Shape of train images: (759, 330, 330, 3)
# Shape of train labels: (759,)

# %%
from sklearn.model_selection import train_test_split
X_train, X_val, y_train, y_val = train_test_split(Train_Imgs, Train_Lbls, shuffle = True, test_size = 0.2, random_state = 42)
print('Shape of X_train: {}, y_train: {} '.format(X_train.shape, y_train.shape))
print('Shape of X_val: {}, y_val: {} '.format(X_val.shape, y_val.shape))
# Out:
# Shape of X_train: (607, 330, 330, 3), y_train: (607,)
# Shape of X_val: (152, 330, 330, 3), y_val: (152,)

# %%
from random import randint
dim = 4

f,ax = plt.subplots(dim,dim) 
f.subplots_adjust(0,0,2,2)
for i in range(0,dim):
    for j in range(0,dim):
        rnd_number = randint(0,len(Train_Imgs))
        cl = Train_Lbls[rnd_number]
        ax[i,j].imshow(Train_Imgs[rnd_number])
        ax[i,j].set_title(CLASSES[cl]+': ' + str(cl))
        ax[i,j].axis('off')

# %%
def edge_and_cut(img):
    try:
        edges = cv2.Canny(img, img_w, img_h)            
        
        if(np.count_nonzero(edges)>edges.size/10000):           
            pts = np.argwhere(edges>0)
            y1,x1 = pts.min(axis=0)
            y2,x2 = pts.max(axis=0)
            
            new_img = img[y1:y2, x1:x2]          
            new_img = cv2.resize(new_img,(img_w, img_h))  
        else:
            new_img = cv2.resize(img,(img_w, img_h))
    
    except Exception as e:
        print(e)
        new_img = cv2.resize(img,(img_w, img_h))
    
    return new_img

# %%
def show_cropped(img):
    emb_img = img.copy()
    edges = cv2.Canny(img, img_w, img_h)
    
    if(np.count_nonzero(edges)>edges.size/10000):
        pts = np.argwhere(edges>0)
        y1,x1 = pts.min(axis=0)
        y2,x2 = pts.max(axis=0)

        new_img = img[y1:y2, x1:x2]  

        edge_size = 1           

        emb_img[y1-edge_size:y1+edge_size, x1:x2] = [255, 0, 0]
        emb_img[y2-edge_size:y2+edge_size, x1:x2] = [255, 0, 0]
        emb_img[y1:y2, x1-edge_size:x1+edge_size] = [255, 0, 0]
        emb_img[y1:y2, x2-edge_size:x2+edge_size] = [255, 0, 0]

        new_img = cv2.resize(new_img,(img_w, img_h))    
        
    else:
        new_img = cv2.resize(img,(img_w, img_h))
    
    fig, ax = plt.subplots(nrows=1, ncols=4, figsize=(10, 10))
    ax[0].imshow(img, cmap='gray')
    ax[0].set_title('Original Image', fontsize=14)
    ax[1].imshow(edges, cmap='gray')
    ax[1].set_title('Canny Edges', fontsize=14)
    ax[2].imshow(emb_img, cmap='gray')
    ax[2].set_title('Bounding Box', fontsize=14)       
    ax[3].imshow(new_img, cmap='gray')
    ax[3].set_title('Cropped', fontsize=14)

# %%
for x in range(0,3):
    show_cropped(Train_Imgs[randint(0,len(Train_Imgs))])

# %%
def crop_images(Imgs):
    CroppedImages = np.ndarray(shape=(len(Imgs), img_w, img_h, 3), dtype=np.int)

    ind = 0
    for im in Imgs: 
        x = edge_and_cut(im)
        CroppedImages[ind] = x
        ind += 1

    return CroppedImages

# %%
Train_Imgs = crop_images(Train_Imgs)
print('Final shape of images in train set: {} '.format(Train_Imgs.shape))
# Out:
# Final shape of images in train set: (759, 220, 220, 3)

# %%
from sklearn.model_selection import train_test_split
X_train, X_val, y_train, y_val = train_test_split(Train_Imgs, Train_Lbls, shuffle = True, test_size = 0.2, random_state = 42)
print('Shape of X_train: {}, y_train: {} '.format(X_train.shape, y_train.shape))
print('Shape of X_val: {}, y_val: {} '.format(X_val.shape, y_val.shape))
# Out:
# Shape of X_train: (607, 220, 220, 3), y_train: (607,)
# Shape of X_val: (152, 220, 220, 3), y_val: (152,)

# %%
filters = 32      
kernel_size = 3   
max_pool = 3

# %%
EPOCHS = 75                                
batch_size = 32                             
iter_per_epoch = len(X_train) // batch_size  
val_per_epoch = len(X_val) // batch_size

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, AveragePooling2D
from keras.layers import Activation, Dropout, Flatten, Dense
from keras import optimizers

# %%
model = Sequential()
model.add(Conv2D(batch_size, (kernel_size, kernel_size), activation='relu', padding='same', input_shape=(img_w, img_h, 3))) # 32
model.add(MaxPooling2D((max_pool, max_pool))) #reduce the spatial size of incoming features
model.add(Conv2D(2*batch_size, (kernel_size, kernel_size), activation='relu', padding='same')) # 64
model.add(MaxPooling2D((max_pool, max_pool))) 
model.add(Conv2D(4*batch_size, (kernel_size, kernel_size), activation='relu', padding='same')) # 128
model.add(MaxPooling2D((max_pool, max_pool))) 
model.add(Conv2D(4*batch_size, (kernel_size, kernel_size), activation='relu', padding='same')) # 128
model.add(AveragePooling2D(pool_size= (2, 2), strides= (2, 2))) 
model.add(Conv2D(4*batch_size, (kernel_size, kernel_size), activation='relu', padding='same')) # 128
model.add(MaxPooling2D((max_pool, max_pool))) 

model.add(Flatten())
model.add(Dropout(0.5))
model.add(Dense(16*batch_size, activation='relu'))                                             # 512
model.add(Dense(87, activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 220, 220, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 73, 73, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 73, 73, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 24, 24, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 24, 24, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 128)         147584
# _________________________________________________________________
# average_pooling2d (AveragePo (None, 4, 4, 128)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 4, 4, 128)         147584
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 1, 1, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 128)               0
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 512)               66048
# _________________________________________________________________
# dense_1 (Dense)              (None, 87)                44631
# =================================================================
# Total params: 499,095
# Trainable params: 499,095
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
from keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(              
        rotation_range=25,
        zoom_range=0.1,
        width_shift_range=0.1,
        height_shift_range=0.1,
        shear_range=0.2,
        horizontal_flip=True
        )

val_datagen = ImageDataGenerator()

# %%
from random import randint
n = randint(0,len(X_train))
samples = np.expand_dims(X_train[n], 0)
it = train_datagen.flow(samples, batch_size=batch_size)
cols = 7
fig, ax = plt.subplots(nrows=1, ncols=cols, figsize=(15, 10))
ax[0].imshow(X_train[n], cmap='gray')
ax[0].set_title('Original', fontsize=10)

for i in range(1,cols):
    batch = it.next()    
    image = batch[0].astype('uint32') 
    ax[i].set_title('augmented {}'.format(i), fontsize=10)
    ax[i].imshow(image, cmap='gray')

# %%
train_gen = train_datagen.flow(X_train, y_train, batch_size=batch_size)
val_gen = val_datagen.flow(X_val, y_val, batch_size=batch_size)

# %%
history = model.fit_generator(
       train_gen,
       steps_per_epoch= iter_per_epoch,
       epochs=EPOCHS, 
       validation_data = val_gen,
       validation_steps = val_per_epoch,
       verbose=1 
       )
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:1915: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/75
# 18/18 [==============================] - 46s 2s/step - loss: 5.2540 - accuracy: 0.2238 - val_loss: 1.3987 - val_accuracy: 0.3203
# Epoch 2/75
# 18/18 [==============================] - 32s 2s/step - loss: 1.4327 - accuracy: 0.3425 - val_loss: 1.3623 - val_accuracy: 0.3047
# Epoch 3/75
# 18/18 [==============================] - 32s 2s/step - loss: 1.4438 - accuracy: 0.2985 - val_loss: 1.2830 - val_accuracy: 0.4688
# Epoch 4/75
# 18/18 [==============================] - 32s 2s/step - loss: 1.3473 - accuracy: 0.3635 - val_loss: 1.3001 - val_accuracy: 0.3984
# Epoch 5/75
# 18/18 [==============================] - 32s 2s/step - loss: 1.3355 - accuracy: 0.3443 - val_loss: 1.1338 - val_accuracy: 0.4844
# Epoch 6/75
# 18/18 [==============================] - 32s 2s/step - loss: 1.2047 - accuracy: 0.4256 - val_loss: 1.0640 - val_accuracy: 0.5781
# Epoch 7/75
# 18/18 [==============================] - 32s 2s/step - loss: 1.1224 - accuracy: 0.5299 - val_loss: 1.0433 - val_accuracy: 0.5703
# Epoch 8/75
# 18/18 [==============================] - 33s 2s/step - loss: 1.0567 - accuracy: 0.5598 - val_loss: 0.9984 - val_accuracy: 0.5859
# Epoch 9/75
# 18/18 [==============================] - 33s 2s/step - loss: 0.9692 - accuracy: 0.6111 - val_loss: 0.9674 - val_accuracy: 0.5078
# Epoch 10/75
# 18/18 [==============================] - 33s 2s/step - loss: 0.9215 - accuracy: 0.6204 - val_loss: 0.9303 - val_accuracy: 0.6562
# Epoch 11/75
# 18/18 [==============================] - 33s 2s/step - loss: 0.9588 - accuracy: 0.6272 - val_loss: 0.9200 - val_accuracy: 0.5938
# Epoch 12/75
# 18/18 [==============================] - 33s 2s/step - loss: 0.9214 - accuracy: 0.6293 - val_loss: 1.1276 - val_accuracy: 0.5391
# Epoch 13/75
# 18/18 [==============================] - 32s 2s/step - loss: 0.8303 - accuracy: 0.6930 - val_loss: 0.7040 - val_accuracy: 0.7188
# Epoch 14/75
# 18/18 [==============================] - 32s 2s/step - loss: 0.8185 - accuracy: 0.6920 - val_loss: 0.6922 - val_accuracy: 0.7656
# Epoch 15/75
# 18/18 [==============================] - 32s 2s/step - loss: 0.7473 - accuracy: 0.7026 - val_loss: 0.4748 - val_accuracy: 0.8672
# Epoch 16/75
# 18/18 [==============================] - 32s 2s/step - loss: 0.5256 - accuracy: 0.8498 - val_loss: 0.6553 - val_accuracy: 0.7266
# Epoch 17/75
# 18/18 [==============================] - 32s 2s/step - loss: 0.6710 - accuracy: 0.7615 - val_loss: 0.4945 - val_accuracy: 0.8516
# Epoch 18/75
# 18/18 [==============================] - 31s 2s/step - loss: 0.6245 - accuracy: 0.8019 - val_loss: 0.4035 - val_accuracy: 0.8906
# Epoch 19/75
# 18/18 [==============================] - 31s 2s/step - loss: 0.4412 - accuracy: 0.8469 - val_loss: 0.4641 - val_accuracy: 0.9062
# Epoch 20/75
# 18/18 [==============================] - 32s 2s/step - loss: 0.5637 - accuracy: 0.8031 - val_loss: 0.4257 - val_accuracy: 0.8672
# Epoch 21/75
# 18/18 [==============================] - 32s 2s/step - loss: 0.5347 - accuracy: 0.8184 - val_loss: 0.2570 - val_accuracy: 0.9141
# Epoch 22/75
# 18/18 [==============================] - 31s 2s/step - loss: 0.3749 - accuracy: 0.8687 - val_loss: 0.3182 - val_accuracy: 0.8750
# Epoch 23/75
# 18/18 [==============================] - 32s 2s/step - loss: 0.4599 - accuracy: 0.8394 - val_loss: 0.3155 - val_accuracy: 0.8906
# Epoch 24/75
# 18/18 [==============================] - 32s 2s/step - loss: 0.3422 - accuracy: 0.8806 - val_loss: 0.3490 - val_accuracy: 0.8984
# Epoch 25/75
# 18/18 [==============================] - 32s 2s/step - loss: 0.3610 - accuracy: 0.8640 - val_loss: 0.2583 - val_accuracy: 0.9219
# Epoch 26/75
# 18/18 [==============================] - 31s 2s/step - loss: 0.3162 - accuracy: 0.8835 - val_loss: 0.2701 - val_accuracy: 0.8984
# Epoch 27/75
# 18/18 [==============================] - 31s 2s/step - loss: 0.2622 - accuracy: 0.9182 - val_loss: 0.2003 - val_accuracy: 0.9375
# Epoch 28/75
# 18/18 [==============================] - 30s 2s/step - loss: 0.3344 - accuracy: 0.9060 - val_loss: 0.3380 - val_accuracy: 0.9062
# Epoch 29/75
# 18/18 [==============================] - 30s 2s/step - loss: 0.2434 - accuracy: 0.9193 - val_loss: 0.1883 - val_accuracy: 0.9453
# Epoch 30/75
# 18/18 [==============================] - 30s 2s/step - loss: 0.2766 - accuracy: 0.9066 - val_loss: 0.8198 - val_accuracy: 0.7969
# Epoch 31/75
# 18/18 [==============================] - 30s 2s/step - loss: 0.4082 - accuracy: 0.8458 - val_loss: 0.2338 - val_accuracy: 0.9453
# Epoch 32/75
# 18/18 [==============================] - 30s 2s/step - loss: 0.3083 - accuracy: 0.9085 - val_loss: 0.1640 - val_accuracy: 0.9531
# Epoch 33/75
# 18/18 [==============================] - 30s 2s/step - loss: 0.2037 - accuracy: 0.9359 - val_loss: 0.2538 - val_accuracy: 0.8984
# Epoch 34/75
# 18/18 [==============================] - 31s 2s/step - loss: 0.2033 - accuracy: 0.9390 - val_loss: 0.1264 - val_accuracy: 0.9531
# Epoch 35/75
# 18/18 [==============================] - 30s 2s/step - loss: 0.2751 - accuracy: 0.9145 - val_loss: 0.1664 - val_accuracy: 0.9453
# Epoch 36/75
# 18/18 [==============================] - 30s 2s/step - loss: 0.2889 - accuracy: 0.8796 - val_loss: 0.1054 - val_accuracy: 0.9688
# Epoch 37/75
# 18/18 [==============================] - 30s 2s/step - loss: 0.1902 - accuracy: 0.9288 - val_loss: 0.1328 - val_accuracy: 0.9609
# Epoch 38/75
# 18/18 [==============================] - 30s 2s/step - loss: 0.2190 - accuracy: 0.9341 - val_loss: 0.1473 - val_accuracy: 0.9453
# Epoch 39/75
# 18/18 [==============================] - 30s 2s/step - loss: 0.1520 - accuracy: 0.9462 - val_loss: 0.0874 - val_accuracy: 0.9766
# Epoch 40/75
# 18/18 [==============================] - 31s 2s/step - loss: 0.1888 - accuracy: 0.9330 - val_loss: 1.0712 - val_accuracy: 0.6484
# Epoch 41/75
# 18/18 [==============================] - 30s 2s/step - loss: 0.6532 - accuracy: 0.7836 - val_loss: 0.4357 - val_accuracy: 0.8516
# Epoch 42/75
# 18/18 [==============================] - 30s 2s/step - loss: 0.3944 - accuracy: 0.8728 - val_loss: 0.1773 - val_accuracy: 0.9609
# Epoch 43/75
# 18/18 [==============================] - 30s 2s/step - loss: 0.2670 - accuracy: 0.9060 - val_loss: 0.3974 - val_accuracy: 0.9141
# Epoch 44/75
# 18/18 [==============================] - 30s 2s/step - loss: 0.3119 - accuracy: 0.8829 - val_loss: 0.2593 - val_accuracy: 0.9219
# Epoch 45/75
# 18/18 [==============================] - 30s 2s/step - loss: 0.2349 - accuracy: 0.9241 - val_loss: 0.1702 - val_accuracy: 0.9453
# Epoch 46/75
# 18/18 [==============================] - 31s 2s/step - loss: 0.1402 - accuracy: 0.9493 - val_loss: 0.0963 - val_accuracy: 0.9609
# Epoch 47/75
# 18/18 [==============================] - 31s 2s/step - loss: 0.1233 - accuracy: 0.9599 - val_loss: 0.1344 - val_accuracy: 0.9453
# Epoch 48/75
# 18/18 [==============================] - 32s 2s/step - loss: 0.1904 - accuracy: 0.9295 - val_loss: 0.1481 - val_accuracy: 0.9766
# Epoch 49/75
# 18/18 [==============================] - 32s 2s/step - loss: 0.1226 - accuracy: 0.9491 - val_loss: 0.1638 - val_accuracy: 0.9609
# Epoch 50/75
# 18/18 [==============================] - 33s 2s/step - loss: 0.1213 - accuracy: 0.9556 - val_loss: 0.1577 - val_accuracy: 0.9609
# Epoch 51/75
# 18/18 [==============================] - 31s 2s/step - loss: 0.7816 - accuracy: 0.7653 - val_loss: 0.5169 - val_accuracy: 0.7891
# Epoch 52/75
# 18/18 [==============================] - 33s 2s/step - loss: 0.4366 - accuracy: 0.8682 - val_loss: 0.2077 - val_accuracy: 0.9375
# Epoch 53/75
# 18/18 [==============================] - 34s 2s/step - loss: 0.2354 - accuracy: 0.9323 - val_loss: 0.1969 - val_accuracy: 0.9609
# Epoch 54/75
# 18/18 [==============================] - 33s 2s/step - loss: 0.2099 - accuracy: 0.9513 - val_loss: 0.1371 - val_accuracy: 0.9688
# Epoch 55/75
# 18/18 [==============================] - 33s 2s/step - loss: 0.1978 - accuracy: 0.9409 - val_loss: 0.3017 - val_accuracy: 0.9219
# Epoch 56/75
# 18/18 [==============================] - 33s 2s/step - loss: 0.2117 - accuracy: 0.9386 - val_loss: 0.1266 - val_accuracy: 0.9766
# Epoch 57/75
# 18/18 [==============================] - 34s 2s/step - loss: 0.2202 - accuracy: 0.9252 - val_loss: 0.1199 - val_accuracy: 0.9688
# Epoch 58/75
# 18/18 [==============================] - 34s 2s/step - loss: 0.2274 - accuracy: 0.9319 - val_loss: 0.0951 - val_accuracy: 0.9844
# Epoch 59/75
# 18/18 [==============================] - 34s 2s/step - loss: 0.1316 - accuracy: 0.9559 - val_loss: 0.1046 - val_accuracy: 0.9688
# Epoch 60/75
# 18/18 [==============================] - 34s 2s/step - loss: 0.1474 - accuracy: 0.9504 - val_loss: 0.1097 - val_accuracy: 0.9688
# Epoch 61/75
# 18/18 [==============================] - 34s 2s/step - loss: 0.1302 - accuracy: 0.9615 - val_loss: 0.1216 - val_accuracy: 0.9609
# Epoch 62/75
# 18/18 [==============================] - 33s 2s/step - loss: 0.1388 - accuracy: 0.9468 - val_loss: 0.1596 - val_accuracy: 0.9688
# Epoch 63/75
# 18/18 [==============================] - 33s 2s/step - loss: 0.1636 - accuracy: 0.9604 - val_loss: 0.0783 - val_accuracy: 0.9844
# Epoch 64/75
# 18/18 [==============================] - 33s 2s/step - loss: 0.1439 - accuracy: 0.9534 - val_loss: 0.1196 - val_accuracy: 0.9609
# Epoch 65/75
# 18/18 [==============================] - 33s 2s/step - loss: 0.1173 - accuracy: 0.9660 - val_loss: 0.1418 - val_accuracy: 0.9688
# Epoch 66/75
# 18/18 [==============================] - 33s 2s/step - loss: 0.1931 - accuracy: 0.9517 - val_loss: 0.1489 - val_accuracy: 0.9609
# Epoch 67/75
# 18/18 [==============================] - 33s 2s/step - loss: 0.1608 - accuracy: 0.9449 - val_loss: 0.0662 - val_accuracy: 0.9844
# Epoch 68/75
# 18/18 [==============================] - 33s 2s/step - loss: 0.1281 - accuracy: 0.9709 - val_loss: 0.0570 - val_accuracy: 0.9844
# Epoch 69/75
# 18/18 [==============================] - 34s 2s/step - loss: 0.0823 - accuracy: 0.9772 - val_loss: 0.1047 - val_accuracy: 0.9688
# Epoch 70/75
# 18/18 [==============================] - 33s 2s/step - loss: 0.1479 - accuracy: 0.9474 - val_loss: 0.3148 - val_accuracy: 0.8750
# Epoch 71/75
# 18/18 [==============================] - 33s 2s/step - loss: 0.1754 - accuracy: 0.9441 - val_loss: 0.0708 - val_accuracy: 0.9844
# Epoch 72/75
# 18/18 [==============================] - 33s 2s/step - loss: 0.1258 - accuracy: 0.9586 - val_loss: 0.2285 - val_accuracy: 0.9453
# Epoch 73/75
# 18/18 [==============================] - 33s 2s/step - loss: 0.1593 - accuracy: 0.9557 - val_loss: 0.3733 - val_accuracy: 0.9219
# Epoch 74/75
# 18/18 [==============================] - 33s 2s/step - loss: 0.1762 - accuracy: 0.9467 - val_loss: 0.1641 - val_accuracy: 0.9531
# Epoch 75/75
# 18/18 [==============================] - 33s 2s/step - loss: 0.2130 - accuracy: 0.9173 - val_loss: 0.1523 - val_accuracy: 0.9688

# %%
#Type 1 of plotting 

f,ax=plt.subplots(2,1) 

#Loss
ax[1].plot(history.history['loss'],color='b',label='Training Loss')
ax[1].plot(history.history['val_loss'],color='r',label='Validation Loss')

#Accuracy
ax[0].plot(history.history['accuracy'],color='b',label='Training  Accuracy')
ax[0].plot(history.history['val_accuracy'],color='r',label='Validation Accuracy')

# %%
#Type 2 of plotting

fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(15,5))
axs[0].plot(history.history['accuracy'])
axs[0].plot(history.history['val_accuracy'])
axs[0].set_title('Model accuracy')
axs[0].legend(['Train', 'Val'], loc='upper left')

axs[1].plot(history.history['loss'])
axs[1].plot(history.history['val_loss'])
axs[1].set_title('Model loss')
axs[1].legend(['Train', 'Val'], loc='upper left')

for ax in axs.flat:
    ax.set(xlabel='Epoch')

# %%
score = model.evaluate_generator(val_gen, steps= len(val_gen))

for idx, metric in enumerate(model.metrics_names):
    print('{}:{}'.format(metric, score[idx]))
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:1948: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   warnings.warn('`Model.evaluate_generator` is deprecated and '
# loss:0.1353951096534729
# accuracy:0.9736841917037964

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns; sns.set_theme()

y_pre_test=model.predict(X_val)
y_pre_test=np.argmax(y_pre_test,axis=1)
cm=confusion_matrix(y_val,y_pre_test)
title='Confusion matrix' 
cmap=plt.cm.Blues
plt.imshow(cm, interpolation='nearest', cmap=cmap)

plt.title(title)
plt.colorbar()
plt.xticks(y_pre_test, rotation=45)
plt.yticks(y_pre_test)


plt.figure(figsize = (5,5))

cm=confusion_matrix(y_val,y_pre_test)
sns.heatmap(cm, annot=True)
plt.tight_layout()

plt.ylabel('True label')

plt.xlabel('Predicted label')
# Out:
# Text(0.5, 21.5, 'Predicted label')

# %%
from sklearn.metrics import confusion_matrix
confusion = confusion_matrix(y_val, y_pre_test)
print('Confusion Matrix\n')
print(confusion)
# Out:
# Confusion Matrix
#
# [[42  0  1  0]
#  [ 0 11  3  0]
#  [ 0  0 49  0]
#  [ 0  0  0 46]]

# %%
#importing confusion matrix
from sklearn.metrics import confusion_matrix
confusion = confusion_matrix(y_val, y_pre_test)
print('Confusion Matrix\n')
print(confusion)

#importing accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
print('\nAccuracy: {:.2f}\n'.format(accuracy_score(y_val, y_pre_test)))

print('Micro Precision: {:.2f}'.format(precision_score(y_val, y_pre_test, average='micro')))
print('Micro Recall: {:.2f}'.format(recall_score(y_val, y_pre_test, average='micro')))
print('Micro F1-score: {:.2f}\n'.format(f1_score(y_val, y_pre_test, average='micro')))

print('Macro Precision: {:.2f}'.format(precision_score(y_val, y_pre_test, average='macro')))
print('Macro Recall: {:.2f}'.format(recall_score(y_val, y_pre_test, average='macro')))
print('Macro F1-score: {:.2f}\n'.format(f1_score(y_val, y_pre_test, average='macro')))

print('Weighted Precision: {:.2f}'.format(precision_score(y_val, y_pre_test, average='weighted')))
print('Weighted Recall: {:.2f}'.format(recall_score(y_val, y_pre_test, average='weighted')))
print('Weighted F1-score: {:.2f}'.format(f1_score(y_val, y_pre_test, average='weighted')))

from sklearn.metrics import classification_report
print('\nClassification Report\n')
target_names=['Class 1', 'Class 2', 'Class 3','Class 4']
print(classification_report(y_val, y_pre_test))
# Out:
# Confusion Matrix
#
# [[42  0  1  0]
#  [ 0 11  3  0]
#  [ 0  0 49  0]
#  [ 0  0  0 46]]
#
# Accuracy: 0.97
#
# Micro Precision: 0.97
# Micro Recall: 0.97
# Micro F1-score: 0.97
#
# Macro Precision: 0.98
# Macro Recall: 0.94
# Macro F1-score: 0.96
#
# Weighted Precision: 0.98
# Weighted Recall: 0.97
# Weighted F1-score: 0.97
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99        43
#            1       1.00      0.79      0.88        14
#            2       0.92      1.00      0.96        49
#            3       1.00      1.00      1.00        46
#
#     accuracy                           0.97       152
#    macro avg       0.98      0.94      0.96       152
# weighted avg       0.98      0.97      0.97       152
